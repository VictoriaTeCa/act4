# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cufflinks as cf
from IPython.display import display,HTML
import chart_studio.plotly as py

# %%
#Leo mi archivo.csv
Covid = pd.read_csv("COVID19Mexico.csv")
#Filtro por filas
Covid= Covid.iloc[0:100000,: ]
Covid
# Out:
# /var/folders/32/dx9n7xv16_n1lslpx2t97vcm0000gn/T/ipykernel_4008/445928318.py:2: DtypeWarning:
#
# Columns (39) have mixed types. Specify dtype option on import or set low_memory=False.
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     NaN         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0         NaN
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  ...  OTRO_CASO  \
# 0       2.0           27           23            8.0  ...        2.0
# 1       2.0           25           25            1.0  ...        2.0
# 2       1.0            9            9           14.0  ...        2.0
# 3       1.0            9            9            2.0  ...        1.0
# 4       1.0            9            9            7.0  ...        1.0
# ...     ...          ...          ...            ...  ...        ...
# 99995   1.0           11           15           31.0  ...        2.0
# 99996   2.0           15           15           95.0  ...        1.0
# 99997   2.0           28           28           22.0  ...        1.0
# 99998   1.0           15            9            6.0  ...        1.0
# 99999   1.0            9            9            7.0  ...        2.0
#
#       TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  \
# 0                    2            97                     1
# 1                    2            97                     1
# 2                    1             1                     2
# 3                    2            97                     1
# 4                    2            97                     1
# ...                ...           ...                   ...
# 99995                1             2                     1
# 99996                2            97                     1
# 99997                2            97                     1
# 99998                2            97                     1
# 99999                2            97                     1
#
#        RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                     2.0                    7        99             México
# 1                     2.0                    7        99             México
# 2                    97.0                    3        99             México
# 3                     2.0                    7        99             México
# 4                     2.0                    7        99             México
# ...                   ...                  ...       ...                ...
# 99995                 2.0                    7        99             México
# 99996                 2.0                    7        99             México
# 99997                 1.0                    3        99             México
# 99998                 1.0                    3        99             México
# 99999                 1.0                    3        99             México
#
#        PAIS_ORIGEN  UCI
# 0               97   97
# 1               97   97
# 2               97   97
# 3               97   97
# 4               97   97
# ...            ...  ...
# 99995           97   97
# 99996           97   97
# 99997           97   97
# 99998           97   97
# 99999           97   97
#
# [100000 rows x 41 columns]

# %%
valores_nulos=Covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   1
# ENTIDAD_UM               1
# SEXO                     1
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            1
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     3
# NACIONALIDAD             0
# EMBARAZO                 2
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# TOMA_MUESTRA_ANTIGENO    0
# RESULTADO_ANTIGENO       1
# CLASIFICACION_FINAL      0
# MIGRANTE                 0
# PAIS_NACIONALIDAD        2
# PAIS_ORIGEN              0
# UCI                      0
# dtype: int64

# %%
#contamos con una base de datos que presenta datos nulos, para poder continuar sin los datos faltantes vamos a sacar el promedio de las datos que si están completos y sustituir los faltantes con el promedio. 
Covid["EMBARAZO"]=Covid["EMBARAZO"].fillna(round(Covid["EMBARAZO"].mean(),1))
Covid["EDAD"]=Covid["EDAD"].fillna(round(Covid["EDAD"].mean(),1))
Covid["SECTOR"]=Covid["SECTOR"].fillna(round(Covid["SECTOR"].mean(),1))
Covid["ENTIDAD_UM"]=Covid["ENTIDAD_UM"].fillna(round(Covid["ENTIDAD_UM"].mean(),1))
Covid["SEXO"]=Covid["SEXO"].fillna(round(Covid["SEXO"].mean(),1))
Covid["MUNICIPIO_RES"]=Covid["MUNICIPIO_RES"].fillna(round(Covid["MUNICIPIO_RES"].mean(),1))

# %%
#comprobamos que ya no tenemos datos nulos
valores_nulos=Covid.isnull().sum()
valores_nulos
# Out:
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             1
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               1
# OTRO_CASO                1
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# TOMA_MUESTRA_ANTIGENO    0
# RESULTADO_ANTIGENO       1
# CLASIFICACION_FINAL      0
# MIGRANTE                 0
# PAIS_NACIONALIDAD        2
# PAIS_ORIGEN              0
# UCI                      0
# dtype: int64

# %%
#quitamos los valores nulos de la fila con datos textuales
Covid= Covid.dropna(0)
valores_nulos=Covid.isnull().sum()
valores_nulos
# Out:
# /var/folders/32/dx9n7xv16_n1lslpx2t97vcm0000gn/T/ipykernel_4008/3004251734.py:2: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
# Unnamed: 0               0
# FECHA_ACTUALIZACION      0
# ID_REGISTRO              0
# ORIGEN                   0
# SECTOR                   0
# ENTIDAD_UM               0
# SEXO                     0
# ENTIDAD_NAC              0
# ENTIDAD_RES              0
# MUNICIPIO_RES            0
# TIPO_PACIENTE            0
# FECHA_INGRESO            0
# FECHA_SINTOMAS           0
# FECHA_DEF                0
# INTUBADO                 0
# NEUMONIA                 0
# EDAD                     0
# NACIONALIDAD             0
# EMBARAZO                 0
# HABLA_LENGUA_INDIG       0
# INDIGENA                 0
# DIABETES                 0
# EPOC                     0
# ASMA                     0
# INMUSUPR                 0
# HIPERTENSION             0
# OTRA_COM                 0
# CARDIOVASCULAR           0
# OBESIDAD                 0
# RENAL_CRONICA            0
# TABAQUISMO               0
# OTRO_CASO                0
# TOMA_MUESTRA_LAB         0
# RESULTADO_LAB            0
# TOMA_MUESTRA_ANTIGENO    0
# RESULTADO_ANTIGENO       0
# CLASIFICACION_FINAL      0
# MIGRANTE                 0
# PAIS_NACIONALIDAD        0
# PAIS_ORIGEN              0
# UCI                      0
# dtype: int64

# %%
#se decidio hacer los outliers de la variable de edad ya que es la unica que presenta outliers de todas las demás variables a comparar. 
fig = plt.figure(figsize =(5, 3))
plt.boxplot(Covid["EDAD"]) 
plt.title("Outliers de Edad")
plt.show() #dibujamos el diagrama

# %%
y=Covid["EDAD"]
Limite_Superior= y.mean() + 3*y.std()
Limite_Inferior= y.mean() - 3*y.std()
Covid1= Covid[(y<=Limite_Superior)&(y>=Limite_Inferior)]

# %%
fig = plt.figure(figsize =(5, 3))
plt.boxplot(Covid1["EDAD"]) 
plt.title("Outliers de Edad")
plt.show() #dibujamos el diagrama
#el último diagrama muestra los outliers con la variable de edad ya que es la única que presenta outliers.

# %%
Covid
# Out:
#        Unnamed: 0 FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  \
# 0               0          27/08/2022      1a4a8d       1    12.0        23.0
# 1               1          27/08/2022      01e27d       2     9.0        25.0
# 2               2          27/08/2022      13cf10       2     9.0         9.0
# 3               3          27/08/2022      13c92b       2    12.0         9.0
# 4               4          27/08/2022      04af5f       2    12.0         9.0
# ...           ...                 ...         ...     ...     ...         ...
# 99995       99995          27/08/2022      47548a       2    12.0         9.0
# 99996       99996          27/08/2022      5c2773       2     8.1         9.0
# 99997       99997          27/08/2022      aceb1f       2     4.0        13.9
# 99998       99998          27/08/2022      db2a23       2     4.0         9.0
# 99999       99999          27/08/2022      a88222       2     4.0         9.0
#
#        SEXO  ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  ...  OTRO_CASO  \
# 0       2.0           27           23            8.0  ...        2.0
# 1       2.0           25           25            1.0  ...        2.0
# 2       1.0            9            9           14.0  ...        2.0
# 3       1.0            9            9            2.0  ...        1.0
# 4       1.0            9            9            7.0  ...        1.0
# ...     ...          ...          ...            ...  ...        ...
# 99995   1.0           11           15           31.0  ...        2.0
# 99996   2.0           15           15           95.0  ...        1.0
# 99997   2.0           28           28           22.0  ...        1.0
# 99998   1.0           15            9            6.0  ...        1.0
# 99999   1.0            9            9            7.0  ...        2.0
#
#       TOMA_MUESTRA_LAB RESULTADO_LAB TOMA_MUESTRA_ANTIGENO  \
# 0                    2            97                     1
# 1                    2            97                     1
# 2                    1             1                     2
# 3                    2            97                     1
# 4                    2            97                     1
# ...                ...           ...                   ...
# 99995                1             2                     1
# 99996                2            97                     1
# 99997                2            97                     1
# 99998                2            97                     1
# 99999                2            97                     1
#
#        RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                     2.0                    7        99             México
# 1                     2.0                    7        99             México
# 2                    97.0                    3        99             México
# 3                     2.0                    7        99             México
# 4                     2.0                    7        99             México
# ...                   ...                  ...       ...                ...
# 99995                 2.0                    7        99             México
# 99996                 2.0                    7        99             México
# 99997                 1.0                    3        99             México
# 99998                 1.0                    3        99             México
# 99999                 1.0                    3        99             México
#
#        PAIS_ORIGEN  UCI
# 0               97   97
# 1               97   97
# 2               97   97
# 3               97   97
# 4               97   97
# ...            ...  ...
# 99995           97   97
# 99996           97   97
# 99997           97   97
# 99998           97   97
# 99999           97   97
#
# [99995 rows x 41 columns]

# %%
#Eliminamos columnas innecesarias
Covid1= Covid.drop(['Unnamed: 0'], axis=1)
Covid1
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0              27/08/2022      1a4a8d       1    12.0        23.0   2.0
# 1              27/08/2022      01e27d       2     9.0        25.0   2.0
# 2              27/08/2022      13cf10       2     9.0         9.0   1.0
# 3              27/08/2022      13c92b       2    12.0         9.0   1.0
# 4              27/08/2022      04af5f       2    12.0         9.0   1.0
# ...                   ...         ...     ...     ...         ...   ...
# 99995          27/08/2022      47548a       2    12.0         9.0   1.0
# 99996          27/08/2022      5c2773       2     8.1         9.0   2.0
# 99997          27/08/2022      aceb1f       2     4.0        13.9   2.0
# 99998          27/08/2022      db2a23       2     4.0         9.0   1.0
# 99999          27/08/2022      a88222       2     4.0         9.0   1.0
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... OTRO_CASO  \
# 0               27           23            8.0              1  ...       2.0
# 1               25           25            1.0              1  ...       2.0
# 2                9            9           14.0              1  ...       2.0
# 3                9            9            2.0              1  ...       1.0
# 4                9            9            7.0              1  ...       1.0
# ...            ...          ...            ...            ...  ...       ...
# 99995           11           15           31.0              1  ...       2.0
# 99996           15           15           95.0              1  ...       1.0
# 99997           28           28           22.0              1  ...       1.0
# 99998           15            9            6.0              1  ...       1.0
# 99999            9            9            7.0              1  ...       2.0
#
#       TOMA_MUESTRA_LAB RESULTADO_LAB  TOMA_MUESTRA_ANTIGENO  \
# 0                    2            97                      1
# 1                    2            97                      1
# 2                    1             1                      2
# 3                    2            97                      1
# 4                    2            97                      1
# ...                ...           ...                    ...
# 99995                1             2                      1
# 99996                2            97                      1
# 99997                2            97                      1
# 99998                2            97                      1
# 99999                2            97                      1
#
#        RESULTADO_ANTIGENO  CLASIFICACION_FINAL  MIGRANTE  PAIS_NACIONALIDAD  \
# 0                     2.0                    7        99             México
# 1                     2.0                    7        99             México
# 2                    97.0                    3        99             México
# 3                     2.0                    7        99             México
# 4                     2.0                    7        99             México
# ...                   ...                  ...       ...                ...
# 99995                 2.0                    7        99             México
# 99996                 2.0                    7        99             México
# 99997                 1.0                    3        99             México
# 99998                 1.0                    3        99             México
# 99999                 1.0                    3        99             México
#
#        PAIS_ORIGEN  UCI
# 0               97   97
# 1               97   97
# 2               97   97
# 3               97   97
# 4               97   97
# ...            ...  ...
# 99995           97   97
# 99996           97   97
# 99997           97   97
# 99998           97   97
# 99999           97   97
#
# [99995 rows x 40 columns]

# %%
#Reestructurar el Dataframe
#Primera transformación
Data= Covid.pivot(index='Unnamed: 0', columns='SEXO',  values='EDAD')
Data
# Out:
# SEXO         1.0  1.4   2.0
# Unnamed: 0
# 0            NaN  NaN  49.0
# 1            NaN  NaN  81.0
# 2           58.0  NaN   NaN
# 3           41.0  NaN   NaN
# 4           28.0  NaN   NaN
# ...          ...  ...   ...
# 99995       39.0  NaN   NaN
# 99996        NaN  NaN  32.0
# 99997        NaN  NaN  36.0
# 99998       20.0  NaN   NaN
# 99999       46.0  NaN   NaN
#
# [99995 rows x 3 columns]

# %%
#Sexo = Data[Data.index.isin([1, 10])]


#Sexo.iplot(kind='bar', xTitle='Registro',
                           #yTitle='Edad', title='Muestra de 2 registros')

# %%
# Boxplot o grafico de caja

#Data.iplot(kind='box', xTitle='Género',
                    #yTitle='Edad', title='Rango de edades de los registros por sexo')

# %%
#Histplot o Histograma

Data[[2]].iplot(kind='hist',xTitle='Edad', 
                               title='Distibución de edades de los registros de sexo "2"')
#aqui realizamos el primer commit

# %%
#Segunda Transformación
Data2= Covid.pivot(index='ID_REGISTER', columns='RESULTADO_LAB',  values='EDAD')
Data2

# %%
# Barplot o grafico de barras
Resultado = Data2[Data2.index.isin([1, 4])]

# plotting
Resultado.iplot(kind='bar', xTitle='ID',
                           yTitle='Edad', title='Muestra de 2 resultados')

# %%
# Boxplot o grafico de caja

Data2.iplot(kind='box', xTitle='Resultado',
                    yTitle='Edad', title='Rango de edades de los registros por Resultado')

# %%
#Histplot o Histograma

Data2[[2]].iplot(kind='hist',xTitle='Edad', 
                               title='Distibución de edades de los resultados de laboratorio "2"')
#AQUI realizamos el segundo commit

# %%
#Tercera Transformación
Data3= Covid1.pivot(index='ID', columns='MIGRANTE',  values='EDAD')
Data3

# %%
# Barplot o grafico de barras
Migrante = Data3[Data3.index.isin([1, 99])]

# plotting
Migrante.iplot(kind='bar', xTitle='ID',
                           yTitle='Edad', title='Muestra de 2 registros')

# %%
# Boxplot o grafico de caja

Data3.iplot(kind='box', xTitle='Migrante',
                    yTitle='Edad', title='Rango de edades de los registros por resultado de migrante')

# %%
#Histplot o Histograma

Data3[[99]].iplot(kind='hist',xTitle='Edad', 
                               title='Distibución de edades de los resultados de migrantes "99"')
#aqui realizamos el tercer commit

# %%
#Cuarta Transformación
Data4= Covid1.pivot(index='ID', columns='RESULTADO_ANTIGENO',  values='MUNICIPIO_RES')
Data4

# %%
# Barplot o grafico de barras
Antigeno = Data4[Data4.index.isin([1, 99])]

# plotting
Antigeno.iplot(kind='bar', xTitle='ID',
                           yTitle='MUNICIPIO_RES', title='Muestra de 2 registros')

# %%
# Boxplot o grafico de caja

Data4.iplot(kind='box', xTitle='Antígeno',
                    yTitle='Municipio de residencia', title='Municipio de recidencia de los registros por resultado de antígeno')

# %%
#Histplot o Histograma

Data4[[1]].iplot(kind='hist',xTitle='Municipio de residencia', 
                               title='Municipios de recidencia de los resultados de antígeno "1"')
#aqui realizamos el siguiente commit

# %%
#Quinta Transformación
Data5= Covid1.pivot(index='ID', columns='PAIS_NACIONALIDAD',  values='EDAD')
Data5

# %%
# Barplot o grafico de barras
Nacionalidad = Data5[Data5.index.isin([1, 99])]

# plotting
Nacionalidad.iplot(kind='bar', xTitle='ID',
                           yTitle='EDAD', title='Muestra de 2 registros')

# %%
# Boxplot o grafico de caja

Data5.iplot(kind='box', xTitle='Nacionalidad',
                    yTitle='Edad', title='Edades de los registros por nacionalidad')

# %%
#Histplot o Histograma

Data5[["México"]].iplot(kind='hist',xTitle='Edad', 
                               title='Edades de los resultados de nacionalidad de México')
#quinto commit
